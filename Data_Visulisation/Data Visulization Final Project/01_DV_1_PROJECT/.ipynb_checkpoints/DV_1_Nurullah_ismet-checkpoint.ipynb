# %% [markdown]
# ![yaz%C4%B1.png](attachment:yaz%C4%B1.png)

# %% [markdown]
# <div class="alert alert-block alert-info alert">
#
# # <span style=" color:red">WELCOME!
#
# Welcome to "Bike Demand Visualization Project" which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.</span>

# %% [markdown]
# <div class="alert alert-block alert-success ">
#
# ## <span style=" color:red">Determines
#
# Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# "weather_code" category description:
#
# - 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# - 2 = scattered clouds / few clouds
# - 3 = Broken clouds
# - 4 = Cloudy
# - 7 = Rain/ light Rain shower/ Light rain
# - 10 = rain with thunderstorm
# - 26 = snowfall
# - 94 = Freezing Fog
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc. Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.
#
# # <span style=" color:red">Tasks
# </span>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">1. Import Libraries
# </span>

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">2. Read Dataset
# </span>

# %%
df = pd.read_csv("store_sharing.csv", encoding = "windows-1252")
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0  \
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">3. Check missing values and if there are any dublicate rows or not.
# </span>

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
df.isna().sum()[df.isna().sum() > 0] #Bring only if gretaer than 0.
# Out:
# Series([], dtype: int64)

# %%
duplicates = df.duplicated().any()
duplicates
# Out:
# False

# %%
df.isna().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">4. Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)
# </span>

# %%
df['season'].replace(1.0, 'Summer', inplace=True)
df['season'].replace(2.0, 'Fall', inplace=True)
df['season'].replace(3.0, 'Winter', inplace=True)
df['season'].replace(0.0, 'Spring', inplace=True)
df['is_holiday'].replace(1.0, 'Holiday', inplace=True)
df['is_holiday'].replace(0.0, 'Non-holiday', inplace=True)
df['is_weekend'].replace(1.0, 'Weekend', inplace=True)
df['is_weekend'].replace(0.0, 'Non-weekend', inplace=True)
df['weather_code'].replace(1.0, 'Clear', inplace=True)
df['weather_code'].replace(2.0, 'scattered clouds', inplace=True)
df['weather_code'].replace(3.0, 'Broken clouds', inplace=True)
df['weather_code'].replace(4.0, 'Cloudy', inplace=True)
df['weather_code'].replace(7.0, 'Rain', inplace=True)
df['weather_code'].replace(10.0, 'rain with thunderstorm', inplace=True)
df['weather_code'].replace(26.0, 'snowfall', inplace=True)
df['weather_code'].replace(94.0, 'Freezing Fog', inplace=True)

# %%
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed   weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0  Broken clouds
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0          Clear
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0          Clear
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0          Clear
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5          Clear
#
#     is_holiday is_weekend  season
# 0  Non-holiday    Weekend  Winter
# 1  Non-holiday    Weekend  Winter
# 2  Non-holiday    Weekend  Winter
# 3  Non-holiday    Weekend  Winter
# 4  Non-holiday    Weekend  Winter

# %%
new_df = pd.DataFrame({'date': df['timestamp'], 'ct': df['cnt']})
new_df
# Out:
#                       date    ct
# 0      2015-01-04 00:00:00   182
# 1      2015-01-04 01:00:00   138
# 2      2015-01-04 02:00:00   134
# 3      2015-01-04 03:00:00    72
# 4      2015-01-04 04:00:00    47
# ...                    ...   ...
# 17409  2017-01-03 19:00:00  1042
# 17410  2017-01-03 20:00:00   541
# 17411  2017-01-03 21:00:00   337
# 17412  2017-01-03 22:00:00   224
# 17413  2017-01-03 23:00:00   139
#
# [17414 rows x 2 columns]

# %%
new_df['date'] = pd.to_datetime(new_df['date'])

# Extract day information and assign it to the "timestamp" column
new_df['date'] = new_df['date'].dt.day_name()

# %%
new_df
# Out:
#           date    ct
# 0       Sunday   182
# 1       Sunday   138
# 2       Sunday   134
# 3       Sunday    72
# 4       Sunday    47
# ...        ...   ...
# 17409  Tuesday  1042
# 17410  Tuesday   541
# 17411  Tuesday   337
# 17412  Tuesday   224
# 17413  Tuesday   139
#
# [17414 rows x 2 columns]

# %%
new_df_days = new_df.groupby('date')['ct'].count()
new_df_days
# Out:
# date
# Friday       2450
# Monday       2508
# Saturday     2465
# Sunday       2505
# Thursday     2492
# Tuesday      2505
# Wednesday    2489
# Name: ct, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=new_df, x="date", y="ct");
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
plt.figure(figsize=(6,3))
sns.barplot(data=df, x="is_holiday", y="cnt");
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">

# %%
plt.figure(figsize=(6,3))
sns.barplot(data=df, x="is_weekend", y="cnt");
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df, x="weather_code", y="cnt")
plt.show();
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %% [markdown]
# # weather_code
# sns.countplot(x='weather_code',data=df)
#
# 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# 2 = scattered clouds / few clouds
# 3 = Broken clouds
# 4 = Cloudy
# 7 = Rain/ light Rain shower/ Light rain
# 10 = rain with thunderstorm
# 26 = snowfall
# 94 = Freezing Fog

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">5. Look at the data type of each variable, transform timestamp in type, and set it as index.
# </span>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  object
#  7   is_holiday    17414 non-null  object
#  8   is_weekend    17414 non-null  object
#  9   season        17414 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 1.3+ MB

# %%
df = df.set_index('timestamp')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17414 entries, 2015-01-04 00:00:00 to 2017-01-03 23:00:00
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cnt           17414 non-null  int64
#  1   t1            17414 non-null  float64
#  2   t2            17414 non-null  float64
#  3   hum           17414 non-null  float64
#  4   wind_speed    17414 non-null  float64
#  5   weather_code  17414 non-null  object
#  6   is_holiday    17414 non-null  object
#  7   is_weekend    17414 non-null  object
#  8   season        17414 non-null  object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 1.3+ MB

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed   weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0  Broken clouds
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0          Clear
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0          Clear
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0          Clear
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5          Clear
#
#                       is_holiday is_weekend  season
# timestamp
# 2015-01-04 00:00:00  Non-holiday    Weekend  Winter
# 2015-01-04 01:00:00  Non-holiday    Weekend  Winter
# 2015-01-04 02:00:00  Non-holiday    Weekend  Winter
# 2015-01-04 03:00:00  Non-holiday    Weekend  Winter
# 2015-01-04 04:00:00  Non-holiday    Weekend  Winter

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">6. Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)
# </span>

# %% [markdown]
# ![Screenshot%202021-10-27%20164721.png](attachment:Screenshot%202021-10-27%20164721.png)

# %%
#df['day_of_week'] = df['timestamp'].dt.day_name()
#Normal way

# %%
df.index = pd.to_datetime(df.index)
df['day_of_week'] = df.index.day_name()
df['day_of_month'] = df.index.day
df['hour'] = df.index.hour
df['month'] = df.index.month
df['season'] = df.index.quarter
df['year'] = df.index.year

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed   weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0  Broken clouds
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0          Clear
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0          Clear
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0          Clear
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5          Clear
#
#                       is_holiday is_weekend  season day_of_week  day_of_month  \
# timestamp
# 2015-01-04 00:00:00  Non-holiday    Weekend       1      Sunday             4
# 2015-01-04 01:00:00  Non-holiday    Weekend       1      Sunday             4
# 2015-01-04 02:00:00  Non-holiday    Weekend       1      Sunday             4
# 2015-01-04 03:00:00  Non-holiday    Weekend       1      Sunday             4
# 2015-01-04 04:00:00  Non-holiday    Weekend       1      Sunday             4
#
#                      hour  month  year
# timestamp
# 2015-01-04 00:00:00     0      1  2015
# 2015-01-04 01:00:00     1      1  2015
# 2015-01-04 02:00:00     2      1  2015
# 2015-01-04 03:00:00     3      1  2015
# 2015-01-04 04:00:00     4      1  2015

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">7. Visualize the correlation with a heatmap
# </span>

# %%
sns.heatmap(df.corr(), annot=True)
plt.show();

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">8. Visualize the correlation of the target variable and the other features with barplot
# </span>

# %% [markdown]
# ![Screenshot%202021-10-27%20170237.png](attachment:Screenshot%202021-10-27%20170237.png)

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">9. Plot bike shares over time use lineplot.
# </span>

# %%
sns.barplot(data=df, x="year", y="cnt");

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">10. Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot).
# </span>

# %%
fig, ax = plt.subplots(3,1, figsize=(10,10))

sns.lineplot(data=df, x = "month", y="cnt",hue="year", ax =ax[0])
sns.pointplot(data=df, x = "month", y="cnt",hue="year", ax =ax[1])
sns.barplot(data=df, x = "month",y="cnt" ,hue="year", ax =ax[2])

plt.show();

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">11. Plot bike shares by hours on (holidays, weekend, season).
# </span>

# %%
fig, ax = plt.subplots(3,1, figsize=(10,10))

sns.lineplot(data=df, x = "hour", y="cnt",hue="is_holiday", ax =ax[0])
sns.pointplot(data=df, x = "hour", y="cnt",hue="is_weekend", ax =ax[1])
sns.barplot(data=df, x = "hour",y="cnt" ,hue="season", ax =ax[2])

plt.show();

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 12. Plot bike shares by day of week.
#
# - You may want to see whether it is a holiday or not
# </span>

# %%
# Set the figure size
plt.figure(figsize=(10, 8))

# Create the bar plot
sns.barplot(data=df, x="day_of_week", y="cnt", hue="is_holiday")

# Move the legend to the top-right position
plt.legend(loc='upper right', bbox_to_anchor=(1.00, 1))

# Display the plot
plt.show()

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 13. Plot bike shares by day of month
# </span>

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))

sns.lineplot(data=df, x="day_of_month", y="cnt", ax=ax)

plt.show();
# Out:
# <img src="data:image/png;base64,..." width="899.9999804930258">

# %%
# Set the figure size
plt.figure(figsize=(10, 8))

# Create the bar plot
sns.barplot(data=df, x="day_of_month", y="cnt")

# Display the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 14. Plot bike shares by year
#
# - Plot bike shares on holidays by seasons
# </span>

# %%
sns.barplot(data=df, x="year", y="cnt", hue="season");

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">15. Visualize the distribution of bike shares by weekday/weekend with piechart and barplot
# </span>

# %%
df_pie = df.groupby(['is_weekend'])["cnt"].count().reset_index()
df_pie
# Out:
#     is_weekend    cnt
# 0  Non-weekend  12444
# 1      Weekend   4970

# %%
df_pie.value_counts().index
# Out:
# MultiIndex([('Non-weekend', 12444),
#             (    'Weekend',  4970)],
#            names=['is_weekend', 'cnt'])

# %%
# Create subplots
fig, ax = plt.subplots(3, 1, figsize=(10, 10))

# Pie chart
ax[0].pie(x=df_pie.cnt, labels=df_pie.is_weekend, autopct='%1.1f%%')
ax[0].set_title('Distribution of bike shares by weekday/weekend with piechart')

sns.barplot(data=df_pie, x="is_weekend", y="cnt", ax=ax[1])
ax[1].set_title('Bar Plot: Count vs. is_weekend')

# Bar plot
sns.barplot(data=df, x="is_weekend", y="cnt", hue="season", ax=ax[2])
ax[2].set_title('Bar Plot: Count vs. is_weekend')

# Display the plots
plt.show()

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">16. Plot the distribution of weather code by seasons
# </span>

# %%
sns.barplot(data=df, x="season", y="cnt");
plt.show();

# %% [markdown]
# <div class="alert alert-info alert-info ">
#
# # <span style=" color:red">Conclusions
#
#
#
#
# </span>

# %%
# 1. Tatil dönemlerinde degil is günlerinde kullanim daha fazla bu da trafikten kacmak isteyen insanlar icin 
#    alternatif bir cözüm oldugu ve projenin basariya ulastigini gösterebilir.
# 2. Kis aylarinda kullanim daha düsük.
# 3. Ise gelis-gidis saatlerinde kullanim orani daha yüksek ayni sekilde hafta ici kullanim daha yüksek (is günlerinde)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style=" color:red">Thanks for Attending!..
#
#
# </span>

# %% [markdown]
# ![yaz%C4%B1.webp](attachment:yaz%C4%B1.webp)
